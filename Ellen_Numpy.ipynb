# %%
import numpy as np

ar1=np.array([10,20,30,40,50])
print(arr)
# Out:
# [45 67 89 90 76]

# %%
arr2=np.array([[1,2,3],[3,4,5],[5,6,7]])
print(arr2)
# Out:
# [[1 2 3]
#  [3 4 5]
#  [5 6 7]]

# %%
arr3=np.zeros((2,2))
print(arr3)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
arr4=np.ones((2,3))
print(arr4)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
arr5=np.random.randint(1,20,5)
print(arr5)
# Out:
# [ 6  6 16 15 19]

# %%
arr4=np.random.randint(1,30,4).reshape(-1,2)
print(arr4)
# Out:
# [[ 6 22]
#  [ 8 28]]

# %%
print(arr[1:4])
# Out:
# [67 89 90]

# %%
print(arr2.shape)
# Out:
# (3, 3)

# %%
print(arr4.T)
# Out:
# [[ 6  8]
#  [22 28]]

# %%
print(np.mean(arr))
# Out:
# 73.4

# %%
print(np.median(arr))

# %%
import numpy as np
from scipy import stats
arra=np.array([10,20,40,40,20])
print(stats.mode(arra))

# %%
print(np.var(arr))

# %%
print(np.std(arr))

# %%
ar1=np.array([23,56,12,90,34,18,10])
print(np.sort(ar1))

# %%
ar2=np.array([[12,89,34],[23,49,29],[67,89,30]])
print(ar2)

# %%
print(np.sort(ar2,axis=0))

# %%
print(np.sort(ar2,axis=1))

# %%
ar3=np.array([[12,90,34],[25,78,90],[23,12,10]])
print(ar3)

# %%
mat_mul=np.array(ar2*ar3)
print(mat_mul)

# %%
mat_add=np.array(ar2+ar3)
print(mat_add)

# %%
a1=np.array([1,2,3])
a2=np.array([4,5,6])
concat=np.concatenate((a1,a2))
print(concat)

# %%
print(np.unique(concat))

# %%
print(np.linspace(1,10,5))

# %%
print(np.identity(3))

# %%
print(np.eye(3,3))

# %%
data=np.array([12,38,90,89,23,10,4,76])
print(np.argmin(data))

# %%
print(data[6])

# %%
print(np.argmax(data))

# %%
print(data[2])

# %%
print(np.where(data>=40))
# to get actual values instead of index
print(data[data>=40])

# %%
print(np.cumsum(data))

# %%
print(np.corrcoef(a1,a2))
# +1 = strong  positive correlation
#-1 = strong negative correlation

# %%
new_data=np.arange(1,11,1)
print(new_data)

# %%
np.save("new_data.npy",new_data)
loaded=np.load("new_data.npy")
print(loaded)
